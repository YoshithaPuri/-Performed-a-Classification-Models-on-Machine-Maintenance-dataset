# %% [markdown]
# # Predictive Maintenance Dataset

# %% [markdown]
# ## Column Description of Dataset.
#
# 1. UDI: This column likely stands for "Unique Device Identifier" and may contain unique identifiers for each device or product in the dataset.
#
# 2. Product ID: Represents the identification number or code associated with a specific product or device.
#
# 3. Type: Indicates the type or category of the product or device.
#
# 4. Air temperature [K]: Represents the air temperature in Kelvin (K). This could be a measure of the ambient temperature in the environment where the product or device is operating.
#
# 5. Process temperature [K]: Indicates the process temperature in Kelvin (K). This might refer to the temperature of the process or operation involving the product or device.
#
# 6. Rotational speed [rpm]: Represents the rotational speed of some component, likely measured in revolutions per minute (rpm).
#
# 7. Torque [Nm]: Indicates the torque applied, measured in Newton-meters (Nm). Torque is a measure of the rotational force applied to an object.
#
# 8. Tool wear [min]: Represents the amount of tool wear over time, measured in minutes. This could be an indicator of the wear and tear on a tool used in a manufacturing process.
#
# 9. Target: This column likely contains the target variable for a predictive modeling task. It might be the variable that you want to predict or classify.
#
# 10. Failure Type: If present, this column could specify the type of failure or issue that occurred. It might be a categorical variable indicating the reason for failure.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
pip install sklearn.metrics

# %% [markdown]
# ## Reading Dataset

# %%
df=pd.read_csv("/content/drive/MyDrive/Project/predictive_maintenance.csv")
df
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %%
# Create a copy of the dataframe
df_copy = df.copy()
df_copy
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.sample(5)
# Out:
#        UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 7620  7621     L54800    L                300.5                    311.5
# 2504  2505     L49684    L                299.2                    309.1
# 2833  2834     L50013    L                300.3                    309.2
# 1070  1071     M15930    M                296.9                    307.8
# 3045  3046     L50225    L                300.2                    309.4
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 7620                    1651         36.9               65       0
# 2504                    1468         45.6                2       0
# 2833                    1807         26.4              169       0
# 1070                    1477         37.2              160       0
# 3045                    1526         35.3               46       0
#
#      Failure Type
# 7620   No Failure
# 2504   No Failure
# 2833   No Failure
# 1070   No Failure
# 3045   No Failure

# %%
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df.tail()
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure

# %%
df.columns
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air temperature [K]',
#        'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]',
#        'Tool wear [min]', 'Target', 'Failure Type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.size
# Out:
# 100000

# %%
#Target variable are ones and zeros
df['Target'].value_counts()
# Out:
# 0    9661
# 1     339
# Name: Target, dtype: int64

# %%
#Product ID is an identification number
df['Product ID'].value_counts()
# Out:
# M14860    1
# L53850    1
# L53843    1
# L53844    1
# L53845    1
#          ..
# M18193    1
# M18194    1
# L50515    1
# L50516    1
# M24859    1
# Name: Product ID, Length: 10000, dtype: int64

# %%
df['Type'].value_counts()
# Out:
# L    6000
# M    2997
# H    1003
# Name: Type, dtype: int64

# %% [markdown]
# Type column is following a hierarchy but UDI and PRODUCT ID are irrelevant. These columns will be dropped

# %%
# Dropping 'UDI' and 'Product ID' from dataset
df.drop(['UDI', 'Product ID'], axis=1, inplace=True)

# %%
df.isnull()
# Out:
#        Type  Air temperature [K]  Process temperature [K]  \
# 0     False                False                    False
# 1     False                False                    False
# 2     False                False                    False
# 3     False                False                    False
# 4     False                False                    False
# ...     ...                  ...                      ...
# 9995  False                False                    False
# 9996  False                False                    False
# 9997  False                False                    False
# 9998  False                False                    False
# 9999  False                False                    False
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                      False        False            False   False
# 1                      False        False            False   False
# ...

# %%
df.isnull().sum()
# Out:
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
# Taking a look at the data types
df.dtypes
# Out:
# Type                        object
# Air temperature [K]        float64
# Process temperature [K]    float64
# Rotational speed [rpm]       int64
# Torque [Nm]                float64
# Tool wear [min]              int64
# Target                       int64
# Failure Type                object
# dtype: object

# %% [markdown]
# ### Target variables

# %%
# Checking types of failure
df['Failure Type'].value_counts()
# Out:
# No Failure                  9652
# Heat Dissipation Failure     112
# Power Failure                 95
# Overstrain Failure            78
# Tool Wear Failure             45
# Random Failures               18
# Name: Failure Type, dtype: int64

# %% [markdown]
# There are 6 types of Failures.
# We can see that the dataset is highly unbalanced.

# %%
df['Target'].value_counts(normalize=True)
# Out:
# 0    0.9661
# 1    0.0339
# Name: Target, dtype: float64

# %%
df['Target'].value_counts()
# Out:
# 0    9661
# 1     339
# Name: Target, dtype: int64

# %% [markdown]
# The dataset is indeed very unbalanced

# %%
df_failure = df[df['Target'] == 1]
df_failure['Failure Type'].value_counts()
# Out:
# Heat Dissipation Failure    112
# Power Failure                95
# Overstrain Failure           78
# Tool Wear Failure            45
# No Failure                    9
# Name: Failure Type, dtype: int64

# %% [markdown]
# 9 values are classified as failure in the 'Target' variable but as No Failure in the 'Failure Type' variable.

# %%
df_failure[df_failure['Failure Type'] == 'No Failure']
# Out:
#      Type  Air temperature [K]  Process temperature [K]  \
# 1437    H                298.8                    309.9
# 2749    M                299.7                    309.2
# 4044    M                301.9                    310.9
# 4684    M                303.6                    311.8
# 5536    M                302.3                    311.8
# 5941    L                300.6                    310.7
# 6478    L                300.5                    309.8
# 8506    L                298.4                    309.6
# 9015    L                297.2                    308.1
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 1437                    1439         45.2               40       1
# 2749                    1685         28.9              179       1
# 4044                    1419         47.7               20       1
# 4684                    1421         44.8              101       1
# ...

# %% [markdown]
# It could go both ways, either failure or no failure. I think it would make sense to remove those instances since I do not know the real target here.

# %%
index_possible_failure = df_failure[df_failure['Failure Type'] == 'No Failure'].index
df.drop(index_possible_failure, axis=0, inplace=True)

# %% [markdown]
# Let's check the same but for 'Target' variable equal to zero (no failure)

# %%
df_failure = df[df['Target'] == 0]
df_failure['Failure Type'].value_counts()
# Out:
# No Failure         9643
# Random Failures      18
# Name: Failure Type, dtype: int64

# %%
df['Failure Type'].value_counts()
# Out:
# No Failure                  9643
# Heat Dissipation Failure     112
# Power Failure                 95
# Overstrain Failure            78
# Tool Wear Failure             45
# Random Failures               18
# Name: Failure Type, dtype: int64

# %% [markdown]
# we have 18 instances classifed as Random Failures by 'Failure Type', whereas they are classifed as No failure by the 'Target Variable'.

# %% [markdown]
# These 18 instances are in fact all instaces of 'Random Failures'.

# %%
df_failure[df_failure['Failure Type'] == 'Random Failures']
# Out:
#      Type  Air temperature [K]  Process temperature [K]  \
# 1221    M                297.0                    308.3
# 1302    L                298.6                    309.8
# 1748    H                298.4                    307.7
# 2072    L                299.6                    309.5
# 2559    L                299.3                    309.0
# 3065    M                300.1                    309.2
# 3452    H                301.6                    310.5
# 5471    L                302.7                    312.3
# 5489    L                302.6                    312.1
# 5495    H                302.9                    312.5
# 5509    L                302.8                    312.2
# 5553    L                302.5                    311.9
# 5639    L                302.6                    312.1
# 6091    L                300.9                    310.7
# 6913    L                300.8                    311.2
# 6960    L                300.7                    311.0
# ...

# %% [markdown]
# Let's Remove those instances as we do not really know if they belong to Failure class or not.

# %% [markdown]
#  Hence, we will end up with 4 types of failures since 'Random Failures' will be removed altogether.

# %%
index_possible_failure = df_failure[df_failure['Failure Type'] == 'Random Failures'].index
df.drop(index_possible_failure, axis=0, inplace=True)

# %% [markdown]
# 27 instances were removed Of which:
#
# 9 belonged to class Failure in 'Target' variable and No failure in target 'Failure Type'
# 18 belonged to class No failure in 'Target' variable and Random failures in target 'Failure Type'

# %%
# We can see that all 27 instances were removed from the dataset
df.shape
# Out:
# (9973, 8)

# %% [markdown]
# ### Correlation

# %%
sns.pairplot(df, hue='Target', palette='Set2')

# %% [markdown]
# Torque and rotational speed are highly correlated
#
#
#
#
#
#
#
# Process temperature and air temperature are also highly correlated.
#
# We immediately see that failures occur for extreme values of some features, i.e., the machinery fails either for the lowest or largest values of torque and rotational speed.
#
# This is easily spotted in the graph since the orange dots are far apart for those features. So, there is a range for normal conditions in which the machines operate, and above or under this range, they tend to fail.

# %%
colors = ['#637A9F', '#FFB38E']
plt.pie(df['Target'].value_counts(),  explode=[0.1, 0.2], labels=['Not failure', 'Failure'],
        autopct='%1.1f%%', wedgeprops={'edgecolor': 'black'}, shadow=True, startangle=25,
        colors=colors)
plt.title('Failure vs not failure')
plt.tight_layout()
plt.show()

# %% [markdown]
# as mentioned before, highly unbalanced dataset.

# %% [markdown]
# Correllation Heatmap

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# As mentioned before, there is high correlation between process temperature and air temperature, and between rotational speed and torque.

# %%
plt.rcParams["figure.figsize"] = (6,6)
colors = ['#86A3B8', '#DC8686', '#0077A2']
plt.pie(df['Type'].value_counts(), labels=['L', 'M', 'H'], colors=colors,
    autopct='%1.1f%%', wedgeprops={'edgecolor': 'black'}, shadow=True, startangle=25)

plt.title('Percentage of product types')
plt.tight_layout()

# %%
fig, axes = plt.subplots(1,3, figsize=[15,5])
axes.flatten()
j=0
colors = ['#A4CE95','#CCD3CA']
for i in ['L', 'M', 'H']:
    df_product_type = df[df['Type'] == i]
    axes[j].pie(df_product_type['Target'].value_counts(), labels=['Failure', 'Not failure'],
                autopct='%1.2f%%', wedgeprops={'edgecolor': 'black'}, shadow=True, startangle=25,
                colors=colors)
    axes[j].set_title('% of failure for ' + i + ' products')
    j+=1

# %% [markdown]
# L products have a higher ratio of failure compared to the other product types. Moreover, M tends to fail more than H products.

# %% [markdown]
# ### Percentage of Failure types

# %%
columns_failure_type = df['Failure Type'].unique().tolist()  # Types of failures

plt.rcParams["figure.figsize"] = (5,5)
colors = ['#40679E', '#E5E483', '#CCD3CA', '#F2C18D', '#E5E1DA']

plt.pie(df['Failure Type'].value_counts(), explode=(0.2, 0, 0, 0, 0), autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'}, counterclock=False, shadow=True, startangle=25,
        pctdistance=1.1, radius=1.3, colors=colors)
plt.legend(columns_failure_type, loc='lower right', fontsize=10)

plt.title('Percentage of failure types', fontsize=15)
plt.tight_layout()

# %% [markdown]
# Exploring features for each type of failure

# %%
fig, ax = plt.subplots(1,2, figsize=[15,4])
plt.title('Rot. Speed vs Torque wrt Failure Type')
sns.scatterplot(data=df, x='Rotational speed [rpm]', y='Torque [Nm]', hue='Failure Type', palette=['#E9C0CB', '#39A692', '#976EBD', '#ACBF5C', '#DF8B4E'], ax=ax[0])
sns.scatterplot(data=df[df['Target'] == 1], x='Rotational speed [rpm]', y='Torque [Nm]', hue='Failure Type', palette=['#39A692', '#976EBD', '#ACBF5C', '#DF8B4E'], ax=ax[1])

ax[0].set_title('Including class no failure')
ax[1].set_title('Excluding class no failure')
# Out:
# Text(0.5, 1.0, 'Excluding class no failure')

# %% [markdown]
# ### Distribution

# %%
print('Skewness')
fig, axes = plt.subplots(2, 5, figsize=[25,10])
j = 0
colors = ['#E1728F', '#409E7D']

for i in ['Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']:
    sns.histplot(data=df, x=i, kde=True, ax=axes[0,j], hue='Target', palette=colors)
    sns.boxplot(data=df, x=i, ax=axes[1,j], palette=['#9ED2C9'])
    j+=1
    print('{} skewness = {}'.format(i, round(df[i].skew(), 2)))
# Out:
# Skewness
# Air temperature [K] skewness = 0.12
# Process temperature [K] skewness = 0.02
# Rotational speed [rpm] skewness = 1.99
# Torque [Nm] skewness = -0.01
# Tool wear [min] skewness = 0.03

# %% [markdown]
# Rotational speed is positively skewed.
# From the boxplots we can see that 'Rotational speed' and 'Torque' have outliers.

# %%
# Function to calculate the maximum and minumum value from the boxplot
def maximum_box(x):
    Q1 = x.quantile(0.25)
    Q3 = x.quantile(0.75)
    IQR = Q3 - Q1
    maximum = Q3 + 1.5*IQR
    minimum = Q1 - 1.5*IQR
    return maximum, minimum

for i in ['L', 'M', 'H']:
    df_product_type = df[df['Type'] == i]
    max_rotational_speed, min_rotational_speed = maximum_box(df_product_type['Rotational speed [rpm]'])
    max_torque, min_torque= maximum_box(df_product_type['Torque [Nm]'])
    print('Values from boxplot for type product ' + i + ':')
    print(f'Maximum torque value: {round(max_torque,2)}')
    print(f'Minimum torque value: {round(min_torque,2)}')
    print(f'Maximum rotational speed value: {round(max_rotational_speed,2)}')
    print(f'Minimum rotational speed value: {round(min_rotational_speed,2)}')
    print('='*20)
# Out:
# Values from boxplot for type product L:
# Maximum torque value: 67.2
# Minimum torque value: 12.8
# Maximum rotational speed value: 1894.0
# Minimum rotational speed value: 1142.0
# ...
# Values from boxplot for type product M:
# Maximum torque value: 67.05
# Minimum torque value: 13.05
# Maximum rotational speed value: 1895.75
# Minimum rotational speed value: 1137.75
# ...
# Values from boxplot for type product H:
# Maximum torque value: 66.96
# Minimum torque value: 12.66
# Maximum rotational speed value: 1894.38
# Minimum rotational speed value: 1143.38
# ...

# %% [markdown]
# The operational range for torque and rotational speed are similar for all product types.
#
# Values above the maximum and below the minimum might be outliers, but not necessarily.

# %%
max_rotational_speed, min_rotational_speed = maximum_box(df['Rotational speed [rpm]'])
max_torque, min_torque = maximum_box(df['Torque [Nm]'])

max_torque_values = df[df['Torque [Nm]'] >= max_torque]['Type'].value_counts()  # Torque values above the boxplot maximum
min_torque_values = df[df['Torque [Nm]'] <= min_torque]['Type'].value_counts()  # Torque values below the boxplot minimum
max_rotational_speed_values = df[df['Rotational speed [rpm]'] >= max_rotational_speed]['Type'].value_counts()  # Rotational spede values above the boxplot maximum

fig, axes = plt.subplots(1,3, figsize=[15,5])
fig.suptitle('Min and max values wrt product type', fontsize=20)
plt.rcParams['axes.titlesize'] = 16
axes.flatten()
j=0
colors = ['#A4CE95', '#976EBD', '#D37676']

for i in [max_torque_values, min_torque_values, max_rotational_speed_values]:
    axes[j].pie(i, labels=['L', 'M', 'H'], colors=colors,
        autopct='%1.1f%%', wedgeprops={'edgecolor': 'black'}, shadow=True, startangle=25)
    j+=1

axes[0].set_title('Torque above maximum')
axes[1].set_title('Torque below minimum')
axes[2].set_title('Rotational speed above maximum')
plt.tight_layout()

# %% [markdown]
#  The values above the maximum and below the minimum are not highly correlated with the product type. The proportion of the pies is similar to the 60-30-10 proportion of the entire dataset.
#
# However, there are proportionally slightly more values for L products and less for H across the three scenarios.

# %%
total_max_min_values = max_torque_values.sum() + min_torque_values.sum() + max_rotational_speed_values.sum()  # Total of instance under and above the minimum and maximum threshold from the boxplot, respectively.
ratio = total_max_min_values/df.shape[0]  # Percentange of these values with respect to the entire dataset
print('Percentage of values under and above the minimum and maximum threshold from the boxplot: {}'.format(ratio))
# Out:
# Percentage of values under and above the minimum and maximum threshold from the boxplot: 0.048932116715130855

# %% [markdown]
# 4.87% of the instances could be considered as ouliers using the boxplot method.

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn import model_selection
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler

# %%
df=df.sample(frac=1).reset_index(drop=True)

# %%
columns_failure_type = df['Failure Type'].unique().tolist()

# %% [markdown]
# ### Ordinal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler, RobustScaler

# Pass on the categorical values
ord_enc = OrdinalEncoder(categories=[['L', 'M', 'H'], columns_failure_type])

# Fit and transform the data for feature 'Type' and target 'Failure Type'
new_dat = ord_enc.fit_transform(df[['Type', 'Failure Type']])
new_dat
df.drop(['Type', 'Failure Type'], axis=1, inplace=True)

new_df = pd.DataFrame(new_dat,
                      index=df.index,
                      columns=['Type', 'Failure Type'])

df = pd.concat([df, new_df], axis=1)

# %% [markdown]
# ### Scaling data

# %% [markdown]
# Since 'Rotational spede' and 'Torque' have some outliers, I am going to use RobustScaler

# %%
df_scaled = df.copy()
# Scaling Rotational speed and torque with robust scaler:
columns = ['Rotational speed [rpm]', 'Torque [Nm]']
scaler = RobustScaler()
features_scaled = scaler.fit_transform(df[columns])
features_scaled = pd.DataFrame(features_scaled, columns=columns)
df_scaled.drop(columns, axis=1, inplace=True)
df_scaled = pd.concat([df_scaled,features_scaled], axis=1)

df_scaled.head(5)
# Out:
#    Air temperature [K]  Process temperature [K]  Tool wear [min]  Target  \
# 0                302.1                    311.1               86       0
# 1                298.5                    307.9              146       0
# 2                300.1                    309.1               86       0
# 3                302.9                    312.3              175       0
# 4                299.2                    308.6               64       0
#
#    Type  Failure Type  Rotational speed [rpm]  Torque [Nm]
# 0   1.0           0.0               -0.280423     0.851852
# 1   1.0           0.0                0.724868    -0.518519
# 2   0.0           0.0               -0.793651     1.377778
# 3   2.0           0.0                0.031746     0.496296
# 4   1.0           0.0                0.677249    -0.348148

# %% [markdown]
# The rest of the features will be scaled with MinMax scaling

# %%
columns = ['Air temperature [K]', 'Process temperature [K]', 'Tool wear [min]']
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(df[columns])
features_scaled = pd.DataFrame(features_scaled, columns=columns)
df_scaled.drop(columns, axis=1, inplace=True)
df_scaled = pd.concat([df_scaled, features_scaled], axis=1)

df_scaled.head()
# Out:
#    Target  Type  Failure Type  Rotational speed [rpm]  Torque [Nm]  \
# 0       0   1.0           0.0               -0.280423     0.851852
# 1       0   1.0           0.0                0.724868    -0.518519
# 2       0   0.0           0.0               -0.793651     1.377778
# 3       0   2.0           0.0                0.031746     0.496296
# 4       0   1.0           0.0                0.677249    -0.348148
#
#    Air temperature [K]  Process temperature [K]  Tool wear [min]
# 0             0.739130                 0.666667         0.339921
# 1             0.347826                 0.271605         0.577075
# 2             0.521739                 0.419753         0.339921
# 3             0.826087                 0.814815         0.691700
# 4             0.423913                 0.358025         0.252964

# %% [markdown]
# ### Splittting

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['Failure Type','Target'],axis=1)
Y = df[['Target']]
X_train, X_test, y_train, y_test = train_test_split(X,Y, stratify = Y,test_size=0.3,random_state=0,shuffle=True)
print('X_Train Size:', (X_train.shape))
print('X _test Size:', (X_test.shape))
print('Y_train Size:', (y_train.shape))
print('Y_test Size:',(y_test.shape))
# Out:
# X_Train Size: (6981, 6)
# X _test Size: (2992, 6)
# Y_train Size: (6981, 1)
# Y_test Size: (2992, 1)

# %% [markdown]
# ### Balancing the data

# %%
import imblearn
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
y_smt_series = pd.Series(y_train.iloc[:, 0])
y_smt_series.value_counts()
# Out:
# 0    6750
# 1    6750
# Name: Target, dtype: int64

# %% [markdown]
# ## Model Building

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,roc_auc_score
import warnings
warnings.filterwarnings('ignore')
acc_log=[]
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred1=lr.predict(X_test)

y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

print("Train Accuracy:", accuracy_score(y_train,y_pred_train))
print("Train Classification Report:")
print(classification_report(y_train,y_pred_train,digits=4))

print("Test Accuracy:",accuracy_score(y_test,y_pred_test))
print("Test Classification Report:")
print(classification_report(y_test,y_pred_test,digits=4))

cm_test = confusion_matrix(y_test, y_pred_test)
matrix = ConfusionMatrixDisplay(confusion_matrix = cm_test, display_labels = [0, 1])
matrix.plot(cmap="Greens")
plt.title("ConfusionMatrix.", weight="bold");

#ROC(Reciever Operating Characteristic)Curve
from sklearn.metrics import roc_auc_score, roc_curve

# Calculate AUC
auc_score = roc_auc_score(y_test, y_pred_test)

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Train Accuracy: 0.8302222222222222
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8290    0.8321    0.8305      6750
#            1     0.8315    0.8283    0.8299      6750
#
#     accuracy                         0.8302     13500
#    macro avg     0.8302    0.8302    0.8302     13500
# weighted avg     0.8302    0.8302    0.8302     13500
#
# Test Accuracy: 0.8255347593582888
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9938    0.8247    0.9014      2893
#            1     0.1421    0.8485    0.2435        99
#
#     accuracy                         0.8255      2992
#    macro avg     0.5679    0.8366    0.5724      2992
# weighted avg     0.9656    0.8255    0.8796      2992

# %%
#Decision tree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import ConfusionMatrixDisplay
clf_dt = DecisionTreeClassifier(max_depth = 5, random_state=40)
clf_dt.fit(X=X_train, y= y_train)

y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

print("Train Accuracy:", accuracy_score(y_train,y_pred_train))
print("Train Classification Report:")
print(classification_report(y_train,y_pred_train,digits=4))

print("Test Accuracy:",accuracy_score(y_test,y_pred_test))
print("Test Classification Report:")
print(classification_report(y_test,y_pred_test,digits=4))

cm_test = confusion_matrix(y_test, y_pred_test)
matrix = ConfusionMatrixDisplay(confusion_matrix = cm_test, display_labels = [0, 1])
matrix.plot(cmap="Greens")
plt.title("ConfusionMatrix.", weight="bold");

#ROC(Reciever Operating Characteristic)Curve
from sklearn.metrics import roc_auc_score, roc_curve

# Calculate AUC
auc_score = roc_auc_score(y_test, y_pred_test)

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Train Accuracy: 0.9527407407407408
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9799    0.9244    0.9514      6750
#            1     0.9285    0.9810    0.9540      6750
#
#     accuracy                         0.9527     13500
#    macro avg     0.9542    0.9527    0.9527     13500
# weighted avg     0.9542    0.9527    0.9527     13500
#
# Test Accuracy: 0.9174465240641712
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9970    0.9174    0.9555      2893
#            1     0.2758    0.9192    0.4242        99
#
#     accuracy                         0.9174      2992
#    macro avg     0.6364    0.9183    0.6899      2992
# weighted avg     0.9731    0.9174    0.9380      2992

# %%
#Randomforest Classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import ConfusionMatrixDisplay
clf_rf = RandomForestClassifier(max_depth = 4, random_state=40)
clf_rf.fit(X=X_train, y=y_train)

y_pred_train = clf_rf.predict(X_train)
y_pred_test = clf_rf.predict(X_test)

print("Train Accuracy:", accuracy_score(y_train,y_pred_train))
print("Train Classification Report:")
print(classification_report(y_train,y_pred_train,digits=4))

print("Test Accuracy:",accuracy_score(y_test,y_pred_test))
print("Test Classification Report:")
print(classification_report(y_test,y_pred_test,digits=4))

cm_test = confusion_matrix(y_test, y_pred_test)
matrix = ConfusionMatrixDisplay(confusion_matrix = cm_test, display_labels = [0, 1])
matrix.plot(cmap="Greens")
plt.title("ConfusionMatrix.", weight="bold");

#ROC(Reciever Operating Characteristic)Curve
from sklearn.metrics import roc_auc_score, roc_curve

# Calculate AUC
auc_score = roc_auc_score(y_test, y_pred_test)

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Train Accuracy: 0.9328148148148148
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9705    0.8927    0.9300      6750
#            1     0.9007    0.9729    0.9354      6750
#
#     accuracy                         0.9328     13500
#    macro avg     0.9356    0.9328    0.9327     13500
# weighted avg     0.9356    0.9328    0.9327     13500
#
# Test Accuracy: 0.8796791443850267
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9949    0.8801    0.9340      2893
#            1     0.1986    0.8687    0.3233        99
#
#     accuracy                         0.8797      2992
#    macro avg     0.5968    0.8744    0.6286      2992
# weighted avg     0.9686    0.8797    0.9138      2992

# %%
#Support Vector Machines
from sklearn.svm import SVC
from sklearn.metrics import ConfusionMatrixDisplay
clf_svc = SVC()
clf_svc.fit(X=X_train, y= y_train)

y_pred_train = clf_svc.predict(X_train)
y_pred_test = clf_svc.predict(X_test)

print("Train Accuracy:", accuracy_score(y_train,y_pred_train))
print("Train Classification Report:")
print(classification_report(y_train,y_pred_train,digits=4))

print("Test Accuracy:",accuracy_score(y_test,y_pred_test))
print("Test Classification Report:")
print(classification_report(y_test,y_pred_test,digits=4))

cm_test = confusion_matrix(y_test, y_pred_test)
matrix = ConfusionMatrixDisplay(confusion_matrix = cm_test, display_labels = [0, 1])
matrix.plot(cmap="Greens")
plt.title("ConfusionMatrix.", weight="bold");

#ROC(Reciever Operating Characteristic)Curve
from sklearn.metrics import roc_auc_score, roc_curve

# Calculate AUC
auc_score = roc_auc_score(y_test, y_pred_test)

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Train Accuracy: 0.8415555555555555
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8716    0.8012    0.8349      6750
#            1     0.8160    0.8819    0.8477      6750
#
#     accuracy                         0.8416     13500
#    macro avg     0.8438    0.8416    0.8413     13500
# weighted avg     0.8438    0.8416    0.8413     13500
#
# Test Accuracy: 0.8011363636363636
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9923    0.8006    0.8862      2893
#            1     0.1231    0.8182    0.2140        99
#
#     accuracy                         0.8011      2992
#    macro avg     0.5577    0.8094    0.5501      2992
# weighted avg     0.9635    0.8011    0.8639      2992

# %%
#Naive bayes classifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import recall_score
from sklearn import svm
NB1 =  GaussianNB()
NB1=NB1.fit(X_train, y_train)
y_pred_train =NB1.predict(X_train)
y_pred_train[0:10]
y_pred_test = NB1.predict(X_test)
y_pred_test[0:10]
print("trainaccuracy",accuracy_score(y_train,y_pred_train))
print("recall-train",recall_score(y_train,y_pred_train,average='macro'))
print("Train Classification Report:")
print(classification_report(y_train,y_pred_train,digits=4))

print("testaccuracy",accuracy_score(y_test,y_pred_test))
print("recall-test",recall_score(y_test,y_pred_test,average='macro'))
print("Test Classification Report:")
print(classification_report(y_test,y_pred_test,digits=4))

cm_test = confusion_matrix(y_test, y_pred_test)
matrix = ConfusionMatrixDisplay(confusion_matrix = cm_test, display_labels = [0, 1])
matrix.plot(cmap="Greens")
plt.title("ConfusionMatrix.", weight="bold");

#ROC(Reciever Operating Characteristic)Curve
from sklearn.metrics import roc_auc_score, roc_curve

# Calculate AUC
auc_score = roc_auc_score(y_test, y_pred_test)

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# trainaccuracy 0.8391111111111111
# recall-train 0.8391111111111111
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8455    0.8299    0.8376      6750
#            1     0.8330    0.8483    0.8406      6750
#
#     accuracy                         0.8391     13500
#    macro avg     0.8392    0.8391    0.8391     13500
# weighted avg     0.8392    0.8391    0.8391     13500
#
# testaccuracy 0.820855614973262
# recall-test 0.8146867918731037
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9921    0.8213    0.8986      2893
#            1     0.1340    0.8081    0.2299        99
#
#     accuracy                         0.8209      2992
#    macro avg     0.5630    0.8147    0.5643      2992
# weighted avg     0.9637    0.8209    0.8765      2992

# %%
import matplotlib.pyplot as plt

# Define data for bar chart
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'SVM', 'Naive Bayes']
accuracies = [0.90, 0.95, 0.92, 0.88, 0.75]

# Create bar chart
plt.figure(figsize=(10, 5))
plt.bar(models, accuracies, color=['#B0C5A4','#58A399','#B2B377','#7F9F80','#50727B'], width=0.4)

# Add labels and title
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Model Accuracies")

# Add grid and show plot
plt.grid(True)
plt.show()

# %% [markdown]
# Here, it is clear that Decision Tree is performing well.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The Dataset is about Predictive_Maintenance Machines. Start by EDA (Exploratory Data Analysis) as of understanding the dataset, as per dataset we have UDI & Product ID are irrelevant.Type column is following a hierarchy, These columns are dropped, next by removing the non-failure are placed as failure those records have also dropped(Target column).
#
# As per that we have known the dataset is imbalance. Before doing any technique we have applied different model alogirthms to see how it works, as per this accuracies for logistic regression are 0.96 and 0.97, decision tress is 1.00 and 0.99, svm is 0.96 and 0.96, and random forest is 1.00 and 0.96 which is clearly overfitting.
#
# Then after doing encoding,scaling, and balancing the dataset using SMOTE, and along with graphing confusion matrix along with ROC curve in the models. From this we got accuracies like from Logistic Regression with 0.8 and 0.82, Decision Tree with 0.95 and 0.91, Random Forest with 0.93 and 0.87, SVM with
# 0.84 and 0.80, Naive Bayes with 0.83 and 0.82. Here, we can conclude that Decision Tree is performing well.
